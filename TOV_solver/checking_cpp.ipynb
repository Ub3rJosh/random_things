# %%
import numpy as np
from matplotlib import pyplot as plt

import pandas

# %%
# run the cpp code
! g++ TOV_solver.cpp -o ./test_run
# !./test_run

# %%
y = pandas.read_csv("test_file.txt", header=None)

plt.plot(x, y)
plt.show()
